# %%
import cv2
import numpy as np
import math 
import matplotlib.image as mpimg
import sys

# %matplotlib notebook
from matplotlib import pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import os

# %%
print(os.getcwd())
# Out:
# D:\notebook

# %% [markdown]
# # 1.1 Image Color with different libraries

# %%
img = cv2.imread('IMG_9809.jpg')

# %%
rows = 2
columns = 4
fig = plt.figure(figsize=(10, 7))
b, g, r = cv2.split(img)

fig.add_subplot(rows,columns,1)
plt.title('BGR')
plt.imshow(img)
plt.show()

fig.add_subplot(rows,columns,2)
plt.title('B')
plt.imshow(b, cmap = 'gray')
plt.show()

fig.add_subplot(rows,columns,3)
plt.title('G')
plt.imshow(g, cmap = 'gray')
plt.show()

fig.add_subplot(rows,columns,4)
plt.title('R')
plt.imshow(r, cmap = 'gray')
plt.show()

rgb = plt.imread('IMG_9809.jpg')
fig.add_subplot(rows,columns,5)
plt.title('RGB')
plt.imshow(rgb)
plt.show()

rn, gn, bn = cv2.split(rgb)
fig.add_subplot(rows,columns,6)
plt.title('R')
plt.imshow(rn, cmap = 'gray')
plt.show()

fig.add_subplot(rows,columns,7)
plt.title('G')
plt.imshow(gn, cmap = 'gray')
plt.show()

fig.add_subplot(rows,columns,8)
plt.title('B')
plt.imshow(bn, cmap = 'gray')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %% [markdown]
# # 1.2 Image Reshape

# %%
default_img = plt.imread('IMG_9809.jpg')
plt.imshow(default_img)
plt.show()

# %%
print('height, width, channel')
print(default_img.shape) #default 'height, width, chanel'
# Out:
# height, width, channel
# (500, 333, 3)

# %%
#print(default_img)

# %%
img_tranpose = np.transpose(default_img)  #transpose 'channel, width, height'

# %%
print('transposed')
print(img_tranpose.shape)
# Out:
# transposed
# (3, 333, 500)

# %%
new_shape = np.moveaxis(img_tranpose,1,-1)  #switch width height index 
print('switch width height index')
print(new_shape.shape)
# Out:
# switch width height index
# (3, 500, 333)

# %%
print('default: height, width, channel')
print(default_img.shape) #default 'height, width, channel'
print('--------------------------------')
print('new: channel, height, width')
print(new_shape.shape)
# Out:
# default: height, width, channel
# (500, 333, 3)
# --------------------------------
# new: channel, height, width
# (3, 500, 333)

# %% [markdown]
# #  1.3 Reduce Bitdepth using Quantization

# %%
fig2 = plt.figure(figsize=(10, 7))

default_img2 = cv2.imread('18in.JPG')
gray = cv2.cvtColor(default_img2, cv2.COLOR_BGR2GRAY)

fig2.add_subplot(1,2,1)
plt.imshow(gray, cmap='gray')
plt.show()

bit_depth = 3

qlevel = 2**bit_depth  #2^3

# min=0  , max = 255 
smin = 0
smax = 255
fig2.add_subplot(1,2,2)
gray = ((gray-smin)/(smax-smin))*qlevel
gray = gray.astype(np.uint8)
plt.imshow(gray, cmap='gray')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
# def quantize(img, qlevel):
#     for i in img:
#         i = math.floor(((i-0)/(255-0))*qlevel)

# %% [markdown]
# # 1.4  3D Image Surface

# %%
gray_img = cv2.imread('76937540_1281214988716549_578073933429866496_n.jpg',0)
imgresize = cv2.resize(gray_img, (300,300))

gridx,gridy = np.mgrid[0:300,0:300]
fig = plt.figure()

plot3d = fig.add_subplot(111, projection='3d')
plot3d.plot_surface(gridx, gridy, imgresize, cmap='gray')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
